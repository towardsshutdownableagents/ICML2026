# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/carissacullen/IPP/plots/data/LambdaVMetaEpSizeFinal2.csv")

# %%
df.head()
# Out:
#                 Name  train_av_usefulness  train_av_NEUTRALITY  \
# 0     frosty-sweep-4             0.778095             0.822838
# 1       glad-sweep-3             0.775062             0.845437
# 2  efficient-sweep-2             0.773434             0.860532
# 3       fast-sweep-1             0.774236             0.859387
# 4  drawn-snowball-53             0.769942             0.878629
#
#    test_av_usefulness  test_av_NEUTRALITY     State  User        ID  \
# 0            0.722258            0.708933  finished   NaN  naswao3k
# 1            0.726860            0.744100  finished   NaN  shn3fzkg
# 2            0.714317            0.737453  finished   NaN  1o4jna8b
# 3            0.722858            0.757726  finished   NaN  7t7vb6fx
# 4            0.723465            0.755628  finished   NaN  qwc4fk57
#
#                     Created  Runtime  ... lambda_factor  meta_ep_size  \
# 0  2025-06-24T20:02:59.000Z    12887  ...          0.89            32
# ...

# %%
# Out:
# 0      0.89
# 1      0.88
# 2      0.87
# 3      0.86
# 4      0.85
#        ...
# 197    0.90
# 198    0.90
# 199    0.90
# 200    0.90
# 201    0.90
# Name: lambda_factor, Length: 202, dtype: float64

# %%
plt.scatter(df["lambda_factor"],df["meta_ep_size"], alpha=0.2)
plt.yscale("log")

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.scatter(df["train_av_usefulness"],df["train_av_NEUTRALITY"],c=np.log2(df["meta_ep_size"]))
plt.colorbar()
plt.subplot(1,2,2)
plt.scatter(df["train_av_usefulness"],df["train_av_NEUTRALITY"],c=df["lambda_factor"])
plt.colorbar()

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.scatter(df["test_av_usefulness"],df["test_av_NEUTRALITY"],c=np.log2(df["meta_ep_size"]))
plt.colorbar()
plt.subplot(1,2,2)
plt.scatter(df["test_av_usefulness"],df["test_av_NEUTRALITY"],c=df["lambda_factor"])
plt.colorbar()
